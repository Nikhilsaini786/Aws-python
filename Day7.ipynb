# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramsaini786/Aws-python/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #File Handling
#
# 1.   "r"--> Read
# 2.   "w'--> write
# 3.   "a" --> Append

# %%
#read
from google.colab import drive
#drive.mount('/content/drive')
data = open('/content/drive/MyDrive/nikhil.txt', 'r')
data.read()
# Out:
# 'Nikhil saini'

# %%
#read
from google.colab import drive
#drive.mount('/content/drive')
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
# Out:
# 'name,roll no\ndheeraj,123\nkunal,1234\nabhishek,12345\npraveen,12356\nanjali,1234567'

# %%
data = open('/content/drive/MyDrive/nikhil.txt', 'w')
data.write("nikhil jjjjjjjjj")
# Out:
# 16

# %%
data = open('/content/drive/MyDrive/nikhil.txt', 'r')
data.read()
# Out:
# 'nikhil jjjjjjjjj'

# %%
#Write and Read
data = open('/content/drive/MyDrive/nikhil.txt', 'w')
data.write("Ram Ram bhaiyo")
data = open('/content/drive/MyDrive/nikhil.txt', 'r')
data.read()
# Out:
# 'Ram Ram bhaiyo'

# %%
data = open('/content/drive/MyDrive/nikhil.txt', 'r')
data.read()
data= open('/content/drive/MyDrive/nikhil.txt', 'w')
data.write("Good Morning")

data = open('/content/drive/MyDrive/nikhil.txt', 'a')
data.write("  Nikhil  Saini")
# Out:
# 15

# %%
data = open('/content/drive/MyDrive/nikhil.txt', 'r')
data.read()
# Out:
# 'Good Morning  Nikhil  Saini'

# %%
from google.colab import drive
#drive.mount('/content/drive')
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
# Out:
# 'name,roll no\ndheeraj,123\nkunal,1234\nabhishek,12345\npraveen,12356\nanjali,1234567'

# %%
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
data = open('/content/drive/MyDrive/file1.csv', 'w')
data.write('1234')
# Out:
# 4

# %%
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
# Out:
# '1234'

# %%
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
data = open('/content/drive/MyDrive/file1.csv', 'w')
data.write('1234')
data = open('/content/drive/MyDrive/file1.csv','a')
data.write('5678')
# Out:
# 4

# %%
data = open('/content/drive/MyDrive/file1.csv', 'r')
data.read()
# Out:
# '12345678'

# %%
#direct access without drive
data = open('nikhil.txt', 'r')
data.read()
# Out:
# 'Nikhil saini'

# %%
#direct access csv file
data= open('file1.csv', 'r')
data.read()
# Out:
# 'name,roll no\ndheeraj,123\nkunal,1234\nabhishek,12345\npraveen,12356\nanjali,1234567'

# %%
data = open('nikhil.txt', 'r')
data.read()
data = open('nikhil.txt', 'w')
data.write("Good Morning")

data = open('nikhil.txt', 'a')
data.write("  Nikhil  Saini")
# Out:
# 15

# %%
data = open('nikhil.txt', 'r')
data.read()
# Out:
# 'Good Morning  Nikhil  Saini'

# %%
data= open('file1.csv', 'r')
data.read()
data = open('file1.csv', 'w')
data.write('1234')
data = open('file1.csv','a')
data.write('5678')
# Out:
# 4

# %%
data= open('file1.csv', 'r')
data.read()
# Out:
# '12345678'

# %% [markdown]
# #Numpy or pandas
